# %% [markdown]
# # Titanic Dataset - Exploratory Data Analysis (EDA) - Visualizations

# %%
# Required Libraries
import warnings
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# # Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Load the dataset (assuming it's stored locally as 'titanic.csv')
df = pd.read_csv('data/titanic.csv',index_col='PassengerId')

# Display first few rows to verify data
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              Sibling_Spouse  Parents_Child            Ticket    Fare_Npr  \
# PassengerId
# 1                         1              0         A/5 21171   1290.5000
# 2                         1              0          PC 17599  12688.4274
# ...

# %% [markdown]
# ## 1. Bar Plot for Survival Count

# %%
# Bar plot for Survived column
plt.figure(figsize=(6,4))
sns.countplot(x='Survived', data=df, hue='Survived', palette='Set1', legend=False)
plt.title('Count of Survived vs Not Survived')
plt.xlabel('Survived (1 = Yes, 0 = No)')
plt.ylabel('Passenger Count')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. Pie Chart for Passenger Class Distribution

# %%
# Pie chart for Pclass
pclass_counts = df['Pclass'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(pclass_counts, labels=pclass_counts.index, autopct='%1.1f%%', colors=['skyblue', 'orange', 'green'], startangle=180)
plt.title('Passenger Class Distribution')
plt.show()

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    214
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Histogram for Age Distribution

# %%
# Histogram for Age
plt.figure(figsize=(8,5))
sns.histplot(df['Age'].dropna(), bins=20, kde=True, color='purple')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ## 4. Box Plot for Fare Distribution by Passenger Class

# %%
# Box plot for Fare by Pclass
plt.figure(figsize=(8,6))
sns.boxplot(x='Pclass', y='Fare_Npr', data=df, hue='Pclass', palette='coolwarm', legend=False)
plt.title('Fare Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare (NPR)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 5. Violin Plot for Age Distribution by Survival Status

# %%
# Violin plot for Age distribution by Survival
plt.figure(figsize=(8,5))
sns.violinplot(x='Survived', y='Age', data=df,hue='Survived', palette='muted',legend=False)
plt.title('Age Distribution by Survival Status')
plt.xlabel('Survived')
plt.ylabel('Age')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 6. Swarm Plot for Fare by Survival Status and Gender

# %%
# Swarm plot for Fare by Survived and Sex
plt.figure(figsize=(10,6))
sns.swarmplot(x='Survived', y='Fare_Npr', hue='Sex', data=df, palette='bright')
plt.title('Fare Distribution by Survival and Gender')
plt.xlabel('Survived')
plt.ylabel('Fare (NPR)')
plt.legend(title='Sex')
plt.grid(True)
plt.show()
# Out:
# /home/udit/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 42.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/udit/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 9.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/udit/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 57.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/udit/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 24.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 7. Heatmap for Correlation Matrix

# %%
# Correlation heatmap
plt.figure(figsize=(8,6))
corr_matrix = df[['Survived', 'Pclass', 'Age', 'Fare_Npr', 'Sibling_Spouse', 'Parents_Child']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numeric Features')
plt.show()

# %% [markdown]
# ## 8. Pairplot for Visualizing Relationships

# %%
# Pairplot for numerical columns
sns.pairplot(df[['Survived', 'Age', 'Fare_Npr', 'Pclass']], hue='Survived', palette='Set2')
plt.suptitle('Pairplot for Numerical Features', y=1.02)
plt.show()

# %% [markdown]
# ## 9. Bar Plot for Sibling/Spouse Count Distribution

# %%
# Bar plot for Sibling_Spouse
plt.figure(figsize=(8,4))
sns.countplot(x='Sibling_Spouse', data=df, palette='Dark2')
plt.title('Distribution of Sibling/Spouse Count')
plt.xlabel('Sibling/Spouse Count')
plt.ylabel('Passenger Count')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10. Scatter Plot for Fare vs Age Colored by Class

# %%
# Scatter plot for Fare vs Age
plt.figure(figsize=(10,6))
sns.scatterplot(x='Age', y='Fare_Npr', hue='Pclass', data=df, palette='deep')
plt.title('Fare vs Age Scatter Plot by Passenger Class')
plt.xlabel('Age')
plt.ylabel('Fare (NPR)')
plt.grid(True)
plt.show()
